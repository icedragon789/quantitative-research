# %%
from task1 import PredictPrice
class PrototypePricing:
    def __init__(self, units : str, injectionDates : list(str), withdrawalDates : list(str), 
                injectWithdrawalRate : tuple, maxVolume : float, monthlyStorage : float,
                transportCost : float):
        print("PrototypePricing")
        print("injectionDates:"+str(injectionDates))
        print("withdrawalDates:"+str(withdrawalDates))
        
        print("injectWithdrawalRate:"+str(injectWithdrawalRate))
        print("maxVolume:"+str(maxVolume))
        print("monthlyStorage:"+str(monthlyStorage))
        print("transportCost:"+str(transportCost))

        # prices = ...

# %%
units = "MMBtu"
injectionDates = [("6/1/2023", 1000000)]
withdrawalDates = [("10/1/2023", 1000000)]
injectionWithdrawalRate = (10000, 1000000)
maxVolume = 2000000
monthlyStorage = 100000                      # monthly rate
transportCost = 50000

pp = PrototypePricing(units, injectionDates, withdrawalDates, 
                     injectionWithdrawalRate, maxVolume, monthlyStorage,
                     transportCost)
# Out:
# PrototypePricing
# injectionDates:[('6/1/2023', 1000000)]
# withdrawalDates:[('10/1/2023', 1000000)]
# injectWithdrawalRate:(10000, 1000000)
# maxVolume:2000000
# monthlyStorage:100000
# transportCost:50000

# %%
from task1 import PredictPrice
import warnings
import sys

if __name__ == "__main__": 
    # Check if the correct number of arguments is provided
    warnings.filterwarnings('ignore', category=UserWarning)
    warnings.filterwarnings('ignore', category=RuntimeWarning)
    
    if len(sys.argv) < 7:
        print("Usage: python script.py <injectionDates:list(str)>, <withdrawalDates:list(str)>, <prices")
        exit(0)


    # Accessing arguments
    script_name = sys.argv[0]
    first_argument = sys.argv[1]
    pp = PredictPrice(first_argument, 'Nat_Gas.csv')
    print(pp.runner())
# Out:
# Usage: python script.py <injectionDates:list(str)>, <withdrawalDates:list(str)>, <prices
# PredictPrice
# 0.0
